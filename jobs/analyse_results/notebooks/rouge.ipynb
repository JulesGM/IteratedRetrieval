# %%
# !which python
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/mila/g/gagnonju/condaless/bin/python

# %%
import os
os.chdir("/home/mila/g/gagnonju/IteratedDecoding/jobs/analyse_results/")
import plot_rouges

# %%
import pytorch_lightning

# %%
directory = "/home/mila/g/gagnonju/IteratedDecoding/GAR/gar/outputs/answer_with_context_1/"

# %%
import compute_rouge

compute_rouge.main(directory, max_threads=8)
# Out:
# All done!

# %%
plot_rouges.main(directory, smoothing_param=0.3, smoothing_type="exponential")
# Out:
# reading from files.: 100%|██████████| 80/80 [00:00<00:00, 1285.01it/s]

# %%
plot_rouges.main(directory, smoothing_param=3, smoothing_type="conv-lin")
# Out:
# reading from files.: 100%|██████████| 80/80 [00:00<00:00, 1310.82it/s]

# %%
plot_rouges.main(directory, smoothing_param=0.6, smoothing_type="conv-norm")
# Out:
# reading from files.: 100%|██████████| 80/80 [00:00<00:00, 1434.39it/s]
